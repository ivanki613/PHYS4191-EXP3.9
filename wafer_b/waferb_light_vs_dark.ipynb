# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
import scipy.optimize as opt

# %%
data=np.loadtxt('waferb_5_light.csv', delimiter=",",skiprows=2)
#data=np.loadtxt('3.7wafera2nd_test.csv', delimiter=",")
V_exp_5=data.T[0]
C_exp_5=data.T[1]

data=np.loadtxt('waferb_5_off.csv', delimiter=",",skiprows=2)
V_exp_5_off=data.T[0]
C_exp_5_off=data.T[1]

data=np.loadtxt('waferb_5_light_trail2.csv', delimiter=",",skiprows=2)
V_exp_5_light_trail2=data.T[0]
C_exp_5_light_trail2=data.T[1]



#plt.scatter(V_exp_5_light_trail2,C_exp_5_light_trail2, s=10,label='5 on trail2')
#plt.xlabel('Voltage (V)')
#plt.ylabel('Capacitance (F)')
#plt.grid()
#plt.legend(loc='best')
#plt.show()

#print(V_exp)
#print("Voltage: ", V_exp_1)
#print("Capacitance: ", C_exp_1)
plt.scatter(V_exp_5,C_exp_5, s=10,label='5 on')
plt.scatter(V_exp_5_off,C_exp_5_off, s=10,label='5 off')
plt.xlabel('Voltage (V)')
plt.ylabel('Capacitance (F)')
plt.grid()
plt.legend(loc='best')
plt.show()

# %%
plt.scatter(V_exp_1,C_exp_1, s=10,label='1')
plt.scatter(V_exp_5,C_exp_5, s=10,label='5')
plt.xlabel('Voltage (V)')
plt.ylabel('Capacitance (F)')
plt.grid()
plt.legend(loc='best')
plt.show()

plt.scatter(V_exp_1_off,C_exp_1_off, s=10,label='1 off')
plt.scatter(V_exp_5_off,C_exp_5_off, s=10,label='5 off')
plt.xlabel('Voltage (V)')
plt.ylabel('Capacitance (F)')
plt.grid()
plt.legend(loc='best')
plt.show()

# %%
data=np.loadtxt('waferb_14_light.csv', delimiter=",",skiprows=2)
#data=np.loadtxt('3.7wafera2nd_test.csv', delimiter=",")
V_exp_14=data.T[0]
C_exp_14=data.T[1]

data=np.loadtxt('waferb_14_off.csv', delimiter=",",skiprows=2)
V_exp_14_off=data.T[0]
C_exp_14_off=data.T[1]

#print(V_exp)
#print("Voltage: ", V_exp_14_off)
#print("Capacitance: ", C_exp_14_off)
plt.scatter(V_exp_14,C_exp_14, s=10,label='14 on')
plt.scatter(V_exp_14_off,C_exp_14_off, s=10,label='14 off')
plt.xlabel('Voltage (V)')
plt.ylabel('Capacitance (F)')
plt.grid()
plt.legend(loc='best')
plt.show()

# %%
data=np.loadtxt('waferb_17_light.csv', delimiter=",",skiprows=2)
#data=np.loadtxt('3.7wafera2nd_test.csv', delimiter=",")
V_exp_17=data.T[0]
C_exp_17=data.T[1]

data=np.loadtxt('waferb_17_off.csv', delimiter=",",skiprows=2)
V_exp_17_off=data.T[0]
C_exp_17_off=data.T[1]

#print(V_exp)
#print("Voltage: ", V_exp_1)
#print("Capacitance: ", C_exp_1)
plt.scatter(V_exp_17,C_exp_17, s=10,label='17 on')
plt.scatter(V_exp_17_off,C_exp_17_off, s=10,label='17 off')
plt.xlabel('Voltage (V)')
plt.ylabel('Capacitance (F)')
plt.grid()
plt.legend(loc='best')
plt.show()

# %%
data=np.loadtxt('waferb_4_light.csv', delimiter=",",skiprows=2)
#data=np.loadtxt('3.7wafera2nd_test.csv', delimiter=",")
V_exp_4=data.T[0]
C_exp_4=data.T[1]

# %%
data=np.loadtxt('waferb_4_off.csv', delimiter=",",skiprows=2)
#data=np.loadtxt('3.7wafera2nd_test.csv', delimiter=",")
V_exp_4_off=data.T[0]
C_exp_4_off=data.T[1]

# %%
#plt.scatter(V_exp_1,C_exp_1, s=10,label='1 on')
#plt.scatter(V_exp_4,C_exp_4, s=10,label='4 on')
#plt.figure(figsize=(10, 6), dpi=300) #increase resolution
plt.scatter(V_exp_5,C_exp_5, s=10,label='electrode 5 (1mm)^2')
plt.scatter(V_exp_14,C_exp_14, s=10,label='electrode 14 (1.5mm)^2')
plt.scatter(V_exp_17,C_exp_17, s=10,label='electrode 17 (2mm)^2')
plt.title('CV Curve for wafer b with lights on')
plt.xlabel('Voltage (V)')
plt.ylabel('Capacitance (F)')
plt.grid()
plt.legend(loc='best')

# Use scientific notation for the y-axis
ax = plt.gca()  # Get current axes
formatter = ScalarFormatter()
formatter.set_scientific(True)
formatter.set_powerlimits((-3, 3))  # Adjust limits as needed
formatter.useMathText = True
ax.yaxis.set_major_formatter(formatter)

#plt.savefig("CV_light.png")
plt.show()
plt.close()

#plt.scatter(V_exp_1_off,C_exp_1_off, s=10,label='1_off')
#plt.scatter(V_exp_4_off,C_exp_4_off, s=10,label='4_off')
#plt.figure(figsize=(10, 6), dpi=300) #increase resolution
plt.scatter(V_exp_5_off,C_exp_5_off, s=10,label='electrode 5 (1mm)^2')
plt.scatter(V_exp_14_off,C_exp_14_off, s=10,label='electrode 14 (1.5mm)^2')
plt.scatter(V_exp_17_off,C_exp_17_off, s=10,label='electrode 17 (2mm)^2')
plt.title('CV Curve for wafer b with lights off')
plt.xlabel('Voltage (V)')
plt.ylabel('Capacitance (F)')
plt.grid()
plt.legend(loc='best')

# Use scientific notation for the y-axis
ax = plt.gca()  # Get current axes
formatter = ScalarFormatter()
formatter.set_scientific(True)
formatter.set_powerlimits((-3, 3))  # Adjust limits as needed
formatter.useMathText = True
ax.yaxis.set_major_formatter(formatter)

#plt.savefig("CV_off.png")
plt.show()
plt.close()

# %%
#cap per area
#1: 1mm
#5: 1mm
#14: 2mm
#17: 3mm

area_1=(1e-3)**2
area_3=(1e-3)**2
area_4=(1e-3)**2
area_5=(1.01e-3)**2
area_14=(1.5e-3)**2
area_17=(2e-3)**2

C_exp_1_area=C_exp_1/area_1
C_exp_4_area=C_exp_4/area_4
C_exp_5_area=C_exp_5/area_5
C_exp_5_area_trail2=C_exp_5_light_trail2/area_5
C_exp_14_area=C_exp_14/area_14
C_exp_17_area=C_exp_17/area_17

C_exp_1_off_area=C_exp_1_off/area_1
C_exp_3_off_area=C_exp_3_off/area_3
C_exp_4_off_area=C_exp_4_off/area_4
C_exp_5_off_area=C_exp_5_off/area_5
C_exp_14_off_area=C_exp_14_off/area_14
C_exp_17_off_area=C_exp_17_off/area_17


#plt.scatter(V_exp_1_off,C_exp_1_off_area, s=10,label='1 on')
#plt.scatter(V_exp_4_off,C_exp_4_off_area, s=10,label='4 off')
#plt.scatter(V_exp_5,C_exp_5_area, s=10,label='5 on')
#plt.figure(figsize=(10, 6), dpi=300) #increase resolution
plt.scatter(V_exp_5_light_trail2,C_exp_5_area_trail2, s=10,label='electrode 5 (1mm)^2')
plt.scatter(V_exp_14,C_exp_14_area, s=10,label='electrode 14 (1.5mm)^2')
plt.scatter(V_exp_17,C_exp_17_area, s=10,label='electrode 17 (2mm)^2')
plt.title('Capacntance/area versus Voltage for wafer b with lights on')
plt.xlabel('Voltage (V)')
plt.ylabel('Capacitance/area (F/m^2)')
plt.grid()
plt.legend(loc='best')

# Use scientific notation for the y-axis
ax = plt.gca()  # Get current axes
formatter = ScalarFormatter()
formatter.set_scientific(True)
formatter.set_powerlimits((-3, 3))  # Adjust limits as needed
formatter.useMathText = True
ax.yaxis.set_major_formatter(formatter)

#plt.savefig("CV_over_area_on.png")
plt.show()
plt.close()

#plt.scatter(V_exp_1_off,C_exp_1_off_area, s=10,label='1 on')
#plt.scatter(V_exp_4_off,C_exp_4_off_area, s=10,label='4 off')
#plt.figure(figsize=(10, 6), dpi=300) #increase resolution
plt.scatter(V_exp_5_off,C_exp_5_off_area, s=10,label='electrode 5 (1mm)^2')
plt.scatter(V_exp_14_off,C_exp_14_off_area, s=10,label='electrode 14 (1.5mm)^2')
plt.scatter(V_exp_17_off,C_exp_17_off_area, s=10,label='electrode 17 (2mm)^2')
plt.title('Capacntance/area versus Voltage for wafer b with lights off')
plt.xlabel('Voltage (V)')
plt.ylabel('Capacitance/area (F/m^2)')
plt.grid()
plt.legend(loc='best')

# Use scientific notation for the y-axis
ax = plt.gca()  # Get current axes
formatter = ScalarFormatter()
formatter.set_scientific(True)
formatter.set_powerlimits((-3, 3))  # Adjust limits as needed
formatter.useMathText = True
ax.yaxis.set_major_formatter(formatter)

#plt.savefig("CV_over_area_off.png")
plt.show()
plt.close()

#plt.scatter(V_exp_5,C_exp_5_area, s=10,label='5 on')
#plt.scatter(V_exp_14,C_exp_14_area, s=10,label='14 on')
#plt.scatter(V_exp_17,C_exp_17_area, s=10,label='17 on')
#plt.scatter(V_exp_5_off,C_exp_5_off_area, s=10,label='5 off')
#plt.scatter(V_exp_14_off,C_exp_14_off_area, s=10,label='14 off')
#plt.scatter(V_exp_17_off,C_exp_17_off_area, s=10,label='17 off')
#plt.xlabel('Voltage (V)')
#plt.ylabel('Capacitance/area')
#plt.grid()
#plt.legend(loc='best')
#plt.savefig("CV_over_area_on.png")
#plt.show()
#plt.close()

print(C_exp_5_off_area[0])
print(C_exp_14_off_area[0])
print(C_exp_17_off_area[0])

print(C_exp_5_area[0])
print(C_exp_14_area[0])
print(C_exp_17_area[0])
# Out:
# 0.0003548671698853053
# 0.0003462222222222222
# 0.00035
# 0.0003548671698853053
# 0.00034666666666666667
# 0.0003475

# %%
#cap per area
#1: 1mm
#5: 1mm
#14: 2mm
#17: 3mm

C_exp_5_cox=C_exp_5/C_exp_5[0]
C_exp_5_cox_trail2=C_exp_5_light_trail2/C_exp_5_light_trail2[0]
C_exp_14_cox=C_exp_14/C_exp_14[0]
C_exp_17_cox=C_exp_17/C_exp_17[0]

C_exp_5_off_cox=C_exp_5_off/C_exp_5_off[0]
C_exp_14_off_cox=C_exp_14_off/C_exp_14_off[0]
C_exp_17_off_cox=C_exp_17_off/C_exp_17_off[0]


#plt.scatter(V_exp_1_off,C_exp_1_off_area, s=10,label='1 on')
#plt.scatter(V_exp_4_off,C_exp_4_off_area, s=10,label='4 off')
#plt.scatter(V_exp_5,C_exp_5_area, s=10,label='5 on')
#plt.figure(figsize=(10, 6), dpi=300) #increase resolution
plt.scatter(V_exp_5_light_trail2,C_exp_5_cox_trail2, s=10,label='electrode 5 (1mm)^2')
plt.scatter(V_exp_14,C_exp_14_cox, s=10,label='electrode 14 (1.5mm)^2')
plt.scatter(V_exp_17,C_exp_17_cox, s=10,label='electrode 17 (2mm)^2')
plt.title('Capacntance/C_ox versus Voltage for wafer b with lights on')
plt.xlabel('Voltage (V)')
plt.ylabel('C/C_ox')
plt.grid()
plt.legend(loc='best')

# Use scientific notation for the y-axis
ax = plt.gca()  # Get current axes
formatter = ScalarFormatter()
formatter.set_scientific(True)
formatter.set_powerlimits((-3, 3))  # Adjust limits as needed
formatter.useMathText = True
ax.yaxis.set_major_formatter(formatter)

#plt.savefig("CV_over_area_on.png")
plt.show()
plt.close()

#plt.scatter(V_exp_1_off,C_exp_1_off_area, s=10,label='1 on')
#plt.scatter(V_exp_4_off,C_exp_4_off_area, s=10,label='4 off')
#plt.figure(figsize=(10, 6), dpi=300) #increase resolution
plt.scatter(V_exp_5_off,C_exp_5_off_cox, s=10,label='electrode 5 (1mm)^2')
plt.scatter(V_exp_14_off,C_exp_14_off_cox, s=10,label='electrode 14 (1.5mm)^2')
plt.scatter(V_exp_17_off,C_exp_17_off_cox, s=10,label='electrode 17 (2mm)^2')
plt.title('Capacntance/C_ox versus Voltage for wafer b with lights off')
plt.xlabel('Voltage (V)')
plt.ylabel('C/C_ox')
plt.grid()
plt.legend(loc='best')

# Use scientific notation for the y-axis
ax = plt.gca()  # Get current axes
formatter = ScalarFormatter()
formatter.set_scientific(True)
formatter.set_powerlimits((-3, 3))  # Adjust limits as needed
formatter.useMathText = True
ax.yaxis.set_major_formatter(formatter)

#plt.savefig("CV_over_area_off.png")
plt.show()
plt.close()

#plt.scatter(V_exp_5,C_exp_5_area, s=10,label='5 on')
#plt.scatter(V_exp_14,C_exp_14_area, s=10,label='14 on')
#plt.scatter(V_exp_17,C_exp_17_area, s=10,label='17 on')
#plt.scatter(V_exp_5_off,C_exp_5_off_area, s=10,label='5 off')
#plt.scatter(V_exp_14_off,C_exp_14_off_area, s=10,label='14 off')
#plt.scatter(V_exp_17_off,C_exp_17_off_area, s=10,label='17 off')
#plt.xlabel('Voltage (V)')
#plt.ylabel('Capacitance/area')
#plt.grid()
#plt.legend(loc='best')
#plt.savefig("CV_over_area_on.png")
#plt.show()
#plt.close()

print(C_exp_5_off_area[0])
print(C_exp_14_off_area[0])
print(C_exp_17_off_area[0])

print(C_exp_5_area[0])
print(C_exp_14_area[0])
# Out:
# 0.0003548671698853053
# 0.0003462222222222222
# 0.00035
# 0.0003548671698853053
# 0.00034666666666666667

# %%
c_exp_5_cut=C_exp_5_area[100:]
c_exp_14_cut=C_exp_14_area[100:]
c_exp_17_cut=C_exp_17_area[100:]
v_exp_5_cut=V_exp_5[100:]
v_exp_14_cut=V_exp_14[100:]
v_exp_17_cut=V_exp_17[100:]

c_exp_5_off_cut=C_exp_5_off_area[100:]
c_exp_14_off_cut=C_exp_14_off_area[100:]
c_exp_17_off_cut=C_exp_17_off_area[100:]
v_exp_5_off_cut=V_exp_5_off[100:]
v_exp_14_off_cut=V_exp_14_off[100:]
v_exp_17_off_cut=V_exp_17_off[100:]

# Use scientific notation for the y-axis
#plt.figure(figsize=(10, 6), dpi=300)
ax = plt.gca()  # Get current axes
formatter = ScalarFormatter()
formatter.set_scientific(True)
formatter.set_powerlimits((-3, 3))  # Adjust limits as needed
formatter.useMathText = True
ax.yaxis.set_major_formatter(formatter)

plt.scatter(v_exp_5_off_cut,c_exp_5_off_cut, s=10,label='electrode 5 (1mm)^2')
plt.scatter(v_exp_14_off_cut,c_exp_14_off_cut, s=10,label='electrode 14 (1.5mm)^2')
plt.scatter(v_exp_17_off_cut,c_exp_17_off_cut, s=10,label='electrode 17 (2mm)^2')
plt.title('Capacntance/area versus Voltage for wafer b with lights off (inversion)')
plt.xlabel('Voltage (V)')
plt.ylabel('Capacitance/area (F/m^2)')
plt.grid()
plt.legend(loc='best')
#plt.savefig("CV_over_area_inversion_off.png")
plt.show()
plt.close()

# Use scientific notation for the y-axis
#plt.figure(figsize=(10, 6), dpi=300) #increase resolution
ax = plt.gca()  # Get current axes
formatter = ScalarFormatter()
formatter.set_scientific(True)
formatter.set_powerlimits((-3, 3))  # Adjust limits as needed
formatter.useMathText = True
ax.yaxis.set_major_formatter(formatter)

plt.scatter(v_exp_5_cut,c_exp_5_cut, s=10,label='electrode 5 (1mm)^2')
plt.scatter(v_exp_14_cut,c_exp_14_cut, s=10,label='electrode 14 (1.5mm)^2')
plt.scatter(v_exp_17_cut,c_exp_17_cut, s=10,label='electrode 17 (2mm)^2')
plt.title('Capacntance/area versus Voltage for wafer b with lights on (inversion)')
plt.xlabel('Voltage (V)')
plt.ylabel('Capacitance/area (F/m^2)')
plt.grid()
plt.legend(loc='best')
#plt.savefig("CV_over_area_inversion_on.png")
plt.show()
plt.close()
